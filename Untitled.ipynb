# %%
import scholarly
# Out:
# Error occurred during loading data. Trying to use cache server https://fake-useragent.herokuapp.com/browsers/0.1.11
# Traceback (most recent call last):
#   File "/home/hussain/miniconda3/lib/python3.8/site-packages/fake_useragent/utils.py", line 154, in load
#     for item in get_browsers(verify_ssl=verify_ssl):
#   File "/home/hussain/miniconda3/lib/python3.8/site-packages/fake_useragent/utils.py", line 99, in get_browsers
#     html = html.split('<table class="w3-table-all notranslate">')[1]
# IndexError: list index out of range

# %%
dir(scholarly)
# Out:
# ['Author',
#  'DOSException',
#  'MaxTriesExceededException',
#  'ProxyGenerator',
#  'Publication',
#  '_Scholarly',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_navigator',
#  '_proxy_generator',
#  '_scholarly',
#  'author_parser',
#  'data_types',
#  'publication_parser',
#  'scholarly']

# %%
g = scholarly.scholarly.search_author('Samuel Feng')
dir(g)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'close',
#  'gi_code',
#  'gi_frame',
#  'gi_running',
#  'gi_yieldfrom',
#  'send',
#  'throw']

# %%
for i in g:
    print(i)
# Out:
# {'container_type': 'Author', 'filled': [], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'kXBzYrsAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=kXBzYrsAAAAJ', 'name': 'Samuel Feng', 'affiliation': 'Khalifa Unviersity of Science and Technology', 'email_domain': '@ku.ac.ae', 'interests': ['Computational neuroscience', 'Applied Stochastic Processes', 'Renewable Energy Resources'], 'citedby': 345}

# %%
g = scholarly.scholarly.search_author('Samuel Feng')
scholarly.scholarly.fill(i)
# Out:
# {'container_type': 'Author',
#  'filled': ['indices', 'coauthors', 'basics', 'publications', 'counts'],
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#  'scholar_id': 'kXBzYrsAAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=kXBzYrsAAAAJ',
#  'name': 'Samuel Feng',
#  'affiliation': 'Khalifa Unviersity of Science and Technology',
#  'email_domain': '@ku.ac.ae',
#  'interests': ['Computational neuroscience',
#   'Applied Stochastic Processes',
#   'Renewable Energy Resources'],
#  'citedby': 345,
#  'citedby5y': 270,
#  'hindex': 8,
#  'hindex5y': 8,
#  'i10index': 4,
#  'i10index5y': 4,
#  'coauthors': [{'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'NCkkQAMAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Jonathan D. Cohen',
#    'affiliation': 'Professor of Psychology, Co-Director of Princeton Neuroscience Institute, Princeton University'},
# ...

# %%
from bs4 import BeautifulSoup
import requests

URL = "https://www.ku.ac.ae/faculty-directory"
page = requests.get(URL)

# %%
with open('KU_faculty.html', 'w') as html:
    html.writelines(page.text)

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
l = soup.find_all("div", {"class": "blk clear"})

# %%
l[0].find_all("span", {"class": 'name'})
# Out:
# [<span class="name">Dr. Elrashid Yousif Mohd Abbas</span>]

# %%
from time import sleep
from scipy.ran
# Out:
# 352

# %%
import pandas as pd
undoctor = lambda name: name[4:] if name.startswith("Dr. ") else name 
df = pd.DataFrame({
    'name': [blk.find_all("span", {"class": 'name'})[0].text for blk in blks],
    'title': [blk.find_all("span", {"class": 'title'})[0].text for blk in blks],
    'department': [blk.find_all("span", {"class": 'department'})[0].text for blk in blks]
})

df.to_csv('data/KU.csv', index=False)

# %%
df
# Out:
#                                name  ...                                         department
# 0    Dr. Elrashid Yousif Mohd Abbas  ...       department of humanities and social sciences
# 1        Dr. Hamid Ait Abderrahmane  ...               department of mechanical engineering
# 2              Dr. Sufian Abedrabbo  ...                              department of physics
# 3               Dr. Yousef Abosalem  ...                                preparatory program
# 4           Dr. Mohamed Abou-Khousa  ...  department of electrical engineering and compu...
# ..                              ...  ...                                                ...
# 347                   Dr. Bing Zhou  ...                       department of earth sciences
# 348                Dr. Elias Zikkos  ...                                preparatory program
# 349                   Dr. Linda Zou  ...  department of civil infrastructure and environ...
# ...

# %%
blks = soup.find_all("div", {"class": "blk clear"})

for blk in blks:
    name = blk.find_all("span", {"class": 'name'})[0].text
    title = blk.find_all("span", {"class": 'title'})[0].text
    department = blk.find_all("span", {"class": 'department'})[0].text
    
    if name.startswith("Dr. "):
        name = name[4:]

# %%
faculty = []
for i in l:
    name = i.find_all("span", {"class": 'name'})[0].text
    if name.startswith("Dr. "):
        name = name[4:]
    faculty.append(name)

# %%
["scholar_id", "name", "affiliation", "citedby", "hindex"]

# %%
from scholarly import scholarly
import pandas as pd
from tqdm.auto import tqdm

faculty = pd.read_csv("data/KU/KU_faculty.csv")["name"]
keys = ["scholar_id", "name", "affiliation", "citedby", "hindex"]

df = {key: [] for key in keys}
df["directory_name"] = faculty

# %%
for f in tqdm(faculty):
    g = scholarly.search_author(f)
    for i in g:
        details = scholarly.fill(i, sections=['basics', 'indices'])
        for key in keys:
            try:
                df[key].append(details[key])
            except KeyError:
                df[key].append('')
    print(df)


pd.DataFrame(df).to_csv("data/KU/scholar.csv")

# %%
faculty[81]
# Out:
# 'Muhammad Arif'

# %%
list(scholarly.search_author(faculty[81] + " khalifa university"))
# Out:
# [{'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'Gth1jJ8AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=Gth1jJ8AAAAJ',
#   'name': 'Muhammad Arif',
#   'affiliation': 'Khalifa University',
#   'email_domain': '@ku.ac.ae',
#   'interests': ['Wettability',
#    'CO2-storage',
#    'Enhanced oil recovery',
#    'Unconventional reservoirs',
#    'Oil-field chemicals'],
#   'citedby': 1196}]

# %%
list(scholarly.search_author("Khalid Al Ali" + " khalifa university"))
# Out:
# [{'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'ajzSGGwAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=ajzSGGwAAAAJ',
#   'name': 'Khalid Al-Ali',
#   'affiliation': 'Department of Chemical Engineering, Khalifa University of Science and Technology, Abu …',
#   'email_domain': '@ku.ac.ae',
#   'interests': ['Thermochemical',
#    'Solar Fuel Production',
#    'chemical reaction',
#    'catalysis'],
#   'citedby': 388},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'I3y4Kv8AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=I3y4Kv8AAAAJ',
#   'name': 'Khaled Ali Al Jaafari',
#   'affiliation': 'Khalifa University of Science and Technology',
#   'email_domain': '@ku.ac.ae',
# ...

# %%
scholarly.fill(list(scholarly.search_author("Khalid Al Ali"))[0])
# Out:
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# {'container_type': 'Author',
#  'filled': ['indices', 'coauthors', 'basics', 'publications', 'counts'],
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#  'scholar_id': 'TQGTav8AAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=TQGTav8AAAAJ',
#  'name': 'Dr. Khalid k. Ali',
#  'affiliation': 'Mathematics Department, faculty of science, Al-Azhar University',
#  'email_domain': '@azhar.edu.eg',
#  'interests': ['Pure mathematics (Numerical analysis)'],
#  'citedby': 1099,
#  'citedby5y': 1092,
#  'hindex': 19,
#  'hindex5y': 19,
#  'i10index': 35,
#  'i10index5y': 35,
#  'coauthors': [{'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'BvoGTxQAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'K R Raslan',
# ...

# %%
for f in faculty[:10]:
    g = scholarly.scholarly.search_author(f)
    for i in g:
        details = scholarly.scholarly.fill(i)
        print(details, "\n\n\n\n\n")
# Out:
# {'container_type': 'Author', 'filled': ['indices', 'coauthors', 'basics', 'publications', 'counts'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'Rj0VC6gAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=Rj0VC6gAAAAJ', 'name': 'Hamid Ait Abderrahmane', 'affiliation': 'Mechanical Engineering,Khalifa University', 'email_domain': '@ku.ac.ae', 'interests': ['Fluid Mechanics', 'Fluid-Structure Interactions', 'Applied Mathematics'], 'citedby': 358, 'citedby5y': 258, 'hindex': 12, 'hindex5y': 9, 'i10index': 16, 'i10index5y': 8, 'coauthors': [{'container_type': 'Author', 'filled': [], 'scholar_id': 'bWmx9loAAAAJ', 'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>, 'name': 'Hoi Dick Ng', 'affiliation': 'Professor, Gina Cody School of Engineering & Computer Science, Concordia University'}, {'container_type': 'Author', 'filled': [], 'scholar_id': '6wD000EAAAAJ', 'source': <AuthorSource.CO_AUTHORS_LIST: 'C
# ...

# %%
from bs4 import BeautifulSoup
import requests



for i in range(1, 31):
    URL = f'https://www.aus.edu/faculty-hub?page={i}'
    page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
l = soup.find_all("div", {"class": "views-row"})

# %%
l[0].find_all("div", {"class": "title"})[0].text.strip()
# Out:
# 'Dr. Sherri Weiler'

# %%
l[0].find_all("div", {"class": "position"})[0].text.strip()
# Out:
# 'Associate Professor'

# %%
from scholarly import scholarly, ProxyGenerator

pg = ProxyGenerator()
success = pg.SingleProxy(http = <your http proxy>, https = <your https proxy>)
scholarly.use_proxy(pg)
# Out:
#   File "/tmp/ipykernel_22490/203413956.py", line 4
#     success = pg.SingleProxy(http = <your http proxy>, https = <your https proxy>)
#                                     ^
# SyntaxError: invalid syntax
